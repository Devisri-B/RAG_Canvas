# %%
# !pip install canvasapi
# !pip install dotenv
# Out:
# Requirement already satisfied: canvasapi in /Users/devisri/Desktop/Research/Deepsikha/RAG/canvas-self-hosted/.venv/lib/python3.13/site-packages (3.6.0)
# Requirement already satisfied: arrow in /Users/devisri/Desktop/Research/Deepsikha/RAG/canvas-self-hosted/.venv/lib/python3.13/site-packages (from canvasapi) (1.4.0)
# Requirement already satisfied: pytz in /Users/devisri/Desktop/Research/Deepsikha/RAG/canvas-self-hosted/.venv/lib/python3.13/site-packages (from canvasapi) (2026.2)
# Requirement already satisfied: requests in /Users/devisri/Desktop/Research/Deepsikha/RAG/canvas-self-hosted/.venv/lib/python3.13/site-packages (from canvasapi) (2.34.2)
# Requirement already satisfied: python-dateutil>=2.7.0 in /Users/devisri/Desktop/Research/Deepsikha/RAG/canvas-self-hosted/.venv/lib/python3.13/site-packages (from arrow->canvasapi) (2.9.0.post0)
# Requirement already satisfied: tzdata in /Users/devisri/Desktop/Research/Deepsikha/RAG/canvas-self-hosted/.venv/lib/python3.13/site-packages (from arrow->canvasapi) (2026.2)
# Requirement already satisfied: six>=1.5 in /Users/devisri/Desktop/Research/Deepsikha/RAG/canvas-self-hosted/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7.0->arrow->canvasapi) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/devisri/Desktop/Research/Deepsikha/RAG/canvas-self-hosted/.venv/lib/python3.13/site-packages (from requests->canvasapi) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/devisri/Desktop/Research/Deepsikha/RAG/canvas-self-hosted/.venv/lib/python3.13/site-packages (from requests->canvasapi) (3.16)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/devisri/Desktop/Research/Deepsikha/RAG/canvas-self-hosted/.venv/lib/python3.13/site-packages (from requests->canvasapi) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/devisri/Desktop/Research/Deepsikha/RAG/canvas-self-hosted/.venv/lib/python3.13/site-packages (from requests->canvasapi) (2026.5.20)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: dotenv in /Users/devisri/Desktop/Research/Deepsikha/RAG/canvas-self-hosted/.venv/lib/python3.13/site-packages (0.9.9)
# Requirement already satisfied: python-dotenv in /Users/devisri/Desktop/Research/Deepsikha/RAG/canvas-self-hosted/.venv/lib/python3.13/site-packages (from dotenv) (1.2.2)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from canvasapi import Canvas
from dotenv import load_dotenv
import os

load_dotenv()
canvas = Canvas(os.getenv("CANVAS_BASE_URL"), os.getenv("CANVAS_API_TOKEN"))

courses = canvas.get_courses()
for course in courses:
    print(f"ID: {course.id} | Name: {course.name}")
# Out:
# ID: 2 | Name: COMPUTER-SCIENCE-PRINCIPLES

# %%
# Get your specific course
course = canvas.get_course(2)  # use the ID of course

# get files in the course
files = course.get_files()
for f in files:
    print(f.id, f.display_name, f.url)
# Out:
# 36 BigData.pdf http://localhost:3000/files/36/download?download_frd=1&verifier=vIaoLcFGsjS50aQUpOxmeUwCQQMyCX9HkeYctxR0
# 39 binaryCards.sb2 http://localhost:3000/files/39/download?download_frd=1&verifier=e2Z8iCOA6pb8rpG8wovwlfrsryOIZTAGYZRHHTjI
# 5 bundle.js http://localhost:3000/files/5/download?download_frd=1&verifier=SaMsGnI6jNlyiU7FMnlOafPcJY9ZDzIOR6nVqUNT
# 21 Cascading Style Sheets (CSS).pptx http://localhost:3000/files/21/download?download_frd=1&verifier=YoOd4QqjUPSb1lUWHwK81tvcz1W3o8hZfyws9snF
# 6 course-data.js http://localhost:3000/files/6/download?download_frd=1&verifier=29Z29M1E4ahqWwHQHcr9gey8u3paoe2SjEvUQRPK
# 27 CS10051_Syllabus- Spring 2026.pdf http://localhost:3000/files/27/download?download_frd=1&verifier=U5ur46AJRtALBMniDBojpyZ2eSP865ksNb1IeOZe
# 29 cs10051-BitsBytesData (2).pptx http://localhost:3000/files/29/download?download_frd=1&verifier=DynkvffJ1ZAjXJm2QZVrtimQo5OR2qMrptRjUGnC
# 14 CSS, Decimal, Binary, Octal, HEX.pptx http://localhost:3000/files/14/download?download_frd=1&verifier=1EjiUBZPXoGn58uYLpeyKfftSUztBenX4bDbXFAf
# 35 Decimal to Binary.pptx http://localhost:3000/files/35/download?download_frd=1&verifier=LgjMap0mg0Z13s2VTQjxbAblqYwzlNPHAI9EKVl8
# 19 Decimal, Binary, Octal, HEX .pptx http://localhost:3000/files/19/download?download_frd=1&verifier=mNkmIWalqxGLf4zydY3dp4hLV4j8irUtN4XxLeph
# 34 Group Project - Programming a Game.pptx http://localhost:3000/files/34/download?download_frd=1&verifier=bYAk3SmaHlXCeLgTXGXPHyYW01ugA1PWCSxX68Qa
# 24 HTML and introduction to JS.pptx http://localhost:3000/files/24/download?download_frd=1&verifier=FcxF9GMSx16WJgHRc9w0K4HWjHWiULxf7RsATm3h
# 20 HTMLWeb.pptx http://localhost:3000/files/20/download?download_frd=1&verifier=IEkuFRnKaZI2P2moCJQ9tDUnoORu8p1MV8yp15JF
# 4 index.html http://localhost:3000/files/4/download?download_frd=1&verifier=hSsqPW75Jywti9qmBxsiRixZLVKjXYtEnPopJNn5
# 31 JavaScript Functions and DOM .pdf http://localhost:3000/files/31/download?download_frd=1&verifier=5MTAMaL1vLXYIpDCiFc6JelXet2qqR3SE1ciiR84
# 8 JavaScript IF..Else and Loops.pptx http://localhost:3000/files/8/download?download_frd=1&verifier=sJ84Q4OVNdyMEIX4wkJwpyQQRdIFUcQI18hdvKl0
# 13 JavaScript Libraries and APIs.pptx http://localhost:3000/files/13/download?download_frd=1&verifier=NQm612YGHiDjmZBwvWE6CWeVwLqAwDcBTaSXVlSP
# 12 JavaScript Variables, Functions, and Events.pdf http://localhost:3000/files/12/download?download_frd=1&verifier=vjPrB8VjGEYZ89AHY7RpSobee2fRwbCjdQywKz9h
# 23 JavaScript.pdf http://localhost:3000/files/23/download?download_frd=1&verifier=3cozGaK5VGYH3RgRCa8uhVe4bW2Vi98Uyiew2Md8
# 7 Metadata, It’s All Bits (Representation of.pdf http://localhost:3000/files/7/download?download_frd=1&verifier=9Fipt9pyLrnslGoBcA3KMGNFU6gr4GIgVRaMrgri
# 25 Privacy.pdf http://localhost:3000/files/25/download?download_frd=1&verifier=WujzbAiLmEahizTWLbzK0fDURluVikXx6YPlWRuS
# 32 Search Engines.pdf http://localhost:3000/files/32/download?download_frd=1&verifier=i34o1hNb4sLBgUNL8NfXJ5WFbCs1c4ZOS4bhRzzO
# 18 Security.pptx http://localhost:3000/files/18/download?download_frd=1&verifier=pPe8zZbEEU3ffWvzrT6gQIvoRiEGz7ut02BpcaGM
# 15 Social Networks.pptx http://localhost:3000/files/15/download?download_frd=1&verifier=3nnK6DGlXIkY6SHoONOudCgfQXgg3tK6VGUdZ1Xi
# 38 The Internet .pdf http://localhost:3000/files/38/download?download_frd=1&verifier=KI6FjoSHfXftX9iY1whOqBcCp0mZAxRtdsIL0NeT
# 11 Thursday (Binary).pptx http://localhost:3000/files/11/download?download_frd=1&verifier=ywvLNwHaZ44Rx8d1iLLRW4otQ9iS6Cd2TC1yGt5h
# 17 Updated-LabSyllabus-Lab Policies- Spring_2026.pdf http://localhost:3000/files/17/download?download_frd=1&verifier=LvdQgjmQ4QqrHfg16AQYRmx936FX2GyplpSfytNi
# 33 W1a-Welcome Back to Campus.pptx http://localhost:3000/files/33/download?download_frd=1&verifier=hpMeqnQk66fmz69o0EVtPuGopeY7mynyGYiiGYxS
# 26 W3a-Scratch Programming Language.pdf http://localhost:3000/files/26/download?download_frd=1&verifier=HlRQARgjFcLrBv1c0PruN1T8kValX8KS8TCmXIek
# 30 W3b-Procedural Programming & Functional Programming.pptx http://localhost:3000/files/30/download?download_frd=1&verifier=Ozz3PRFjkgBm716qiq9zmPB09uVdFEpHFY9rXpA9
# 16 W4b- Algorithms.pptx http://localhost:3000/files/16/download?download_frd=1&verifier=m2bzRyPGAArnd69cseDvpK3xNBHc69jwiXNx6mGR
# 37 Web server permissions .pdf http://localhost:3000/files/37/download?download_frd=1&verifier=N8H6Ccb64Rsbr0RwFEOaRWiCw97nxinOcBgA9ufU
# 9 webserver permission ssh.mp4 http://localhost:3000/files/9/download?download_frd=1&verifier=AjMiMZPou62DcbvBR55WL7dBTQwolDPUDpLFUo9g
# 22 Week4a-Computational Thinking.pptx http://localhost:3000/files/22/download?download_frd=1&verifier=AHCZvZG51xnFVVjqxuMABDQfz52dRpYpfudDB80i
# 10 Weeks & Topics_Spring_2026.pdf http://localhost:3000/files/10/download?download_frd=1&verifier=mPzBLs38DoWRMvKRQoRYhC4zTOv3qUOEwIgIgK2f
# 28 World Wide Web (WWW).pptx http://localhost:3000/files/28/download?download_frd=1&verifier=46ihicLONE27a78NhdA0sAthe8DEKtneDoxrWv7T
